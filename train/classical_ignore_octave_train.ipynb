# %%
import os
from data import __PATH__

midi_file_path = os.path.join(__PATH__, 'classical')
from data.preprocess import analyse_all_midi
processed_midi_dataset = [x for x in analyse_all_midi(midi_file_path)]
processed_midi_dataset[:10]
# Out:
# [('C:\\Users\\ROG\\Desktop\\large_project\\DeepMidi\\data\\classical\\mz_545_3.mid',
#   [('C_5', 0.25),
#    ('D_5', 0.25),
#    ('E_5', 0.25),
#    ('C_5', 0.25),
#    ('A_4', 0.25),
#    ('F_3', 1.5),
#    ('B_4', 0.25),
#    ('C_5', 0.25),
#    ('C#_5', 0.25),
#    ('D_5', 0.25),
#    ('E_5', 0.25),
#    ('F_5', 0.25),
#    ('D_3', 0.5),
#    ('D_5', 0.25),
#    ('C_5', 0.25),
#    ('G_3', 0.5),
#    ('B_4', 0.25),
#    ('A_4', 0.25),
#    ('G_4', 0.25),
#    ('A_5', 0.25),
#    ('G_5', 0.25),
#    ('F_5', 0.25),
#    ('E_5', 0.25),
#    ('C#_5', 0.25),
#    ('D_5', 0.25),
#    ('E_5', 0.25),
#    ('F_5', 0.25),
#    ('A_4', 0.25),
#    ('C_5', 0.25),
#    ('B_4', 0.25),
#    ('D_5', 0.25),
#    ('C_5', 0.5),
#    ('C_3', 0.25),
#    ('C_5', 0.25),
#    ('D_5', 0.25),
#    ('E_5', 0.25),
#    ('C_5', 0.25),
#    ('A_4', 0.25),
#    ('F_3', 1.5),
#    ('B_4', 0.25),
#    ('C_5', 0.25),
#    ('C#_5', 0.25),
#    ('D_5', 0.25),
#    ('E_5', 0.25),
#    ('F_5', 0.25),
# ...

# %%
for _ in processed_midi_dataset[:1]:
    print([x for x in _])
# Out:
# ['C:\\Users\\ROG\\Desktop\\large_project\\DeepMidi\\data\\classical\\mz_545_3.mid', [('C_5', 0.25), ('D_5', 0.25), ('E_5', 0.25), ('C_5', 0.25), ('A_4', 0.25), ('F_3', 1.5), ('B_4', 0.25), ('C_5', 0.25), ('C#_5', 0.25), ('D_5', 0.25), ('E_5', 0.25), ('F_5', 0.25), ('D_3', 0.5), ('D_5', 0.25), ('C_5', 0.25), ('G_3', 0.5), ('B_4', 0.25), ('A_4', 0.25), ('G_4', 0.25), ('A_5', 0.25), ('G_5', 0.25), ('F_5', 0.25), ('E_5', 0.25), ('C#_5', 0.25), ('D_5', 0.25), ('E_5', 0.25), ('F_5', 0.25), ('A_4', 0.25), ('C_5', 0.25), ('B_4', 0.25), ('D_5', 0.25), ('C_5', 0.5), ('C_3', 0.25), ('C_5', 0.25), ('D_5', 0.25), ('E_5', 0.25), ('C_5', 0.25), ('A_4', 0.25), ('F_3', 1.5), ('B_4', 0.25), ('C_5', 0.25), ('C#_5', 0.25), ('D_5', 0.25), ('E_5', 0.25), ('F_5', 0.25), ('D_3', 0.5), ('D_5', 0.25), ('C_5', 0.25), ('G_3', 0.5), ('B_4', 0.25), ('A_4', 0.25), ('G_4', 0.25), ('A_5', 0.25), ('G_5', 0.25), ('F_5', 0.25), ('E_5', 0.25), ('C#_5', 0.25), ('D_5', 0.25), ('E_5', 0.25), ('F_5', 0.25), ('A_4', 0.25), (
# ...
